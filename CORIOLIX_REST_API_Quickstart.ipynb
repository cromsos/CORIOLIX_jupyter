# %% [markdown]
# # CORIOLIX REST API Documentation
#
# ## EXAMPLE 1: Query the CORIOLIX REST API - Get a list of all REST endpoints

# %%
"""Example script to query the CORIOLIX REST API."""

# Key concepts:
# Use the python requests module to query the REST API
# Use the python json module to parse and dump the json response

# Returns:
# Returns a list of all CORIOLIX REST Endpoints

import requests
import json

# Base URL for Datapresence REST API - MODIFY AS NEEDED
rest_url = 'https://coriolix.ceoas.oregonstate.edu/oceanus/api/?format=json'

# Make the query to the REST API
response = requests.get(rest_url, verify=False)

# Load the response as json data
responseJSON = json.loads(response.text)

# Print all the published endpoints
print(json.dumps(responseJSON, indent=4, sort_keys=True))
# Out:
# {
#     "anemo_mmast": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/anemo_mmast/?format=json",
#     "asset": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/asset/?format=json",
#     "cur_obs": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/cur_obs/?format=json",
#     "cur_obs_archive": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/cur_obs_archive/?format=json",
#     "custom_sensor_1": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/custom_sensor_1/?format=json",
#     "custom_sensor_2": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/custom_sensor_2/?format=json",
#     "custom_sensor_3": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/custom_sensor_3/?format=json",
#     "echo_well": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/echo_well/?format=json",
#     "events": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/events/?format=json",
#     "fluor_flth": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/fluor_flth/?format=json",
#     "gnss_gga_bow": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/gnss_gga_bow/?format=json",
#     "gnss_vtg_bow": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/gnss_vtg_bow/?format=json",
#     "gyro_brdg": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/gyro_brdg/?format=json",
#     "metstn_bow": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/metstn_bow/?format=json",
#     "metstn_stbd": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/metstn_stbd/?format=json",
#     "par_mmast": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/par_mmast/?format=json",
#     "parameter": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/parameter/?format=json",
#     "rad_mmast": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/rad_mmast/?format=json",
#     "rain_mmast": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/rain_mmast/?format=json",
#     "sensor": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor/?format=json",
#     "sensor_float_1": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_float_1/?format=json",
#     "sensor_float_2": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_float_2/?format=json",
#     "sensor_float_3": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_float_3/?format=json",
#     "sensor_float_4": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_float_4/?format=json",
#     "sensor_float_5": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_float_5/?format=json",
#     "sensor_float_6": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_float_6/?format=json",
#     "sensor_float_7": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_float_7/?format=json",
#     "sensor_integer_1": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_integer_1/?format=json",
#     "sensor_log": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_log/?format=json",
#     "sensor_mixed_1": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_mixed_1/?format=json",
#     "sensor_mixed_2": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_mixed_2/?format=json",
#     "sensor_mixed_3": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_mixed_3/?format=json",
#     "sensor_point_1": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/sensor_point_1/?format=json",
#     "speedlog_well": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/speedlog_well/?format=json",
#     "station": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/station/?format=json",
#     "subevent": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/subevent/?format=json",
#     "therm_fwd": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/therm_fwd/?format=json",
#     "therm_hull": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/therm_hull/?format=json",
#     "transmiss_flth": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/transmiss_flth/?format=json",
#     "true_winds": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/true_winds/?format=json",
#     "tsg_flth": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/tsg_flth/?format=json",
#     "user_ship_shapes": "https://coriolix.ceoas.oregonstate.edu/oceanus/api/user_ship_shapes/?format=json"
# }
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ## EXAMPLE 2: Query the CORIOLIX REST API - Get the current sensor observation

# %%
"""Example script to query the CORIOLIX REST API."""

# Key concepts:
# Use the python requests module to query the REST API
# Use the python json module to parse and dump the json response
# Select a specific endpoint to query.

# Returns:
# Returns a list of all currently valid sensor values

import requests
import json

# URL for Datapresence REST endpoint for the current observations table.
rest_url = 'https://coriolix.ceoas.oregonstate.edu/oceanus/api/cur_obs/?format=json'
#rest_url = 'https://coriolix.ceoas.oregonstate.edu/oceanus/api/decimateData/?model=TsgFlth&date_0=2019-10-10%2002:06:55.353%2B00&decfactr=1&format=json'

# Make the query to the REST API
response = requests.get(rest_url, verify=False)

# Load the response as json data
responseJSON = json.loads(response.text)

# Print all current observations
print(json.dumps(responseJSON, indent=4, sort_keys=True))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -149.751801666667,
#                     25.342515
#                 ],
#                 "type": "Point"
#             },
#             "id": 1,
#             "properties": {
#                 "anemo_mmast_collection_date": "2019-10-10T02:07:52.384416Z",
#                 "anemo_mmast_direction": 287.0,
#                 "anemo_mmast_direction_flags": "11111111",
#                 "anemo_mmast_speed": 9.9,
#                 "anemo_mmast_speed_flags": "11111111",
#                 "custom_sensor_1_collection_date": null,
#                 "custom_sensor_1_param_10_integer": null,
#                 "custom_sensor_1_param_10_integer_flags": "99999999",
#                 "custom_sensor_1_param_11_point": null,
#                 "custom_sensor_1_param_11_point_flags": "99999999",
#                 "custom_sensor_1_param_12_point": null,
#                 "custom_sensor_1_param_12_point_flags": "99999999",
#                 "custom_sensor_1_param_13_shortchar": "''",
#                 "custom_sensor_1_param_13_shortchar_flags": "99999999",
#                 "custom_sensor_1_param_14_shortchar": "''",
#                 "custom_sensor_1_param_14_shortchar_flags": "99999999",
#                 "custom_sensor_1_param_15_longchar": "''",
#                 "custom_sensor_1_param_15_longchar_flags": "99999999",
#                 "custom_sensor_1_param_16_longchar": "''",
#                 "custom_sensor_1_param_16_longchar_flags": "99999999",
#                 "custom_sensor_1_param_1_date": null,
#                 "custom_sensor_1_param_1_date_flags": "99999999",
#                 "custom_sensor_1_param_2_date": null,
#                 "custom_sensor_1_param_2_date_flags": "99999999",
#                 "custom_sensor_1_param_3_float": null,
#                 "custom_sensor_1_param_3_float_flags": "99999999",
#                 "custom_sensor_1_param_4_float": null,
#                 "custom_sensor_1_param_4_float_flags": "99999999",
#                 "custom_sensor_1_param_5_float": null,
#                 "custom_sensor_1_param_5_float_flags": "99999999",
#                 "custom_sensor_1_param_6_float": null,
#                 "custom_sensor_1_param_6_float_flags": "99999999",
#                 "custom_sensor_1_param_7_integer": null,
#                 "custom_sensor_1_param_7_integer_flags": "99999999",
#                 "custom_sensor_1_param_8_integer": null,
#                 "custom_sensor_1_param_8_integer_flags": "99999999",
#                 "custom_sensor_1_param_9_integer": null,
#                 "custom_sensor_1_param_9_integer_flags": "99999999",
#                 "custom_sensor_2_collection_date": null,
#                 "custom_sensor_2_param_10_integer": null,
#                 "custom_sensor_2_param_10_integer_flags": "99999999",
#                 "custom_sensor_2_param_11_point": null,
#                 "custom_sensor_2_param_11_point_flags": "99999999",
#                 "custom_sensor_2_param_12_point": null,
#                 "custom_sensor_2_param_12_point_flags": "99999999",
#                 "custom_sensor_2_param_13_shortchar": "''",
#                 "custom_sensor_2_param_13_shortchar_flags": "99999999",
#                 "custom_sensor_2_param_14_shortchar": "''",
#                 "custom_sensor_2_param_14_shortchar_flags": "99999999",
#                 "custom_sensor_2_param_15_longchar": "''",
#                 "custom_sensor_2_param_15_longchar_flags": "99999999",
#                 "custom_sensor_2_param_16_longchar": "''",
#                 "custom_sensor_2_param_16_longchar_flags": "99999999",
#                 "custom_sensor_2_param_1_date": null,
#                 "custom_sensor_2_param_1_date_flags": "99999999",
#                 "custom_sensor_2_param_2_date": null,
#                 "custom_sensor_2_param_2_date_flags": "99999999",
#                 "custom_sensor_2_param_3_float": null,
#                 "custom_sensor_2_param_3_float_flags": "99999999",
#                 "custom_sensor_2_param_4_float": null,
#                 "custom_sensor_2_param_4_float_flags": "99999999",
#                 "custom_sensor_2_param_5_float": null,
#                 "custom_sensor_2_param_5_float_flags": "99999999",
#                 "custom_sensor_2_param_6_float": null,
#                 "custom_sensor_2_param_6_float_flags": "99999999",
#                 "custom_sensor_2_param_7_integer": null,
#                 "custom_sensor_2_param_7_integer_flags": "99999999",
#                 "custom_sensor_2_param_8_integer": null,
#                 "custom_sensor_2_param_8_integer_flags": "99999999",
#                 "custom_sensor_2_param_9_integer": null,
#                 "custom_sensor_2_param_9_integer_flags": "99999999",
#                 "custom_sensor_3_collection_date": null,
#                 "custom_sensor_3_param_10_integer": null,
#                 "custom_sensor_3_param_10_integer_flags": "99999999",
#                 "custom_sensor_3_param_11_point": null,
#                 "custom_sensor_3_param_11_point_flags": "99999999",
#                 "custom_sensor_3_param_12_point": null,
#                 "custom_sensor_3_param_12_point_flags": "99999999",
#                 "custom_sensor_3_param_13_shortchar": "''",
#                 "custom_sensor_3_param_13_shortchar_flags": "99999999",
#                 "custom_sensor_3_param_14_shortchar": "''",
#                 "custom_sensor_3_param_14_shortchar_flags": "99999999",
#                 "custom_sensor_3_param_15_longchar": "''",
#                 "custom_sensor_3_param_15_longchar_flags": "99999999",
#                 "custom_sensor_3_param_16_longchar": "''",
#                 "custom_sensor_3_param_16_longchar_flags": "99999999",
#                 "custom_sensor_3_param_1_date": null,
#                 "custom_sensor_3_param_1_date_flags": "99999999",
#                 "custom_sensor_3_param_2_date": null,
#                 "custom_sensor_3_param_2_date_flags": "99999999",
#                 "custom_sensor_3_param_3_float": null,
#                 "custom_sensor_3_param_3_float_flags": "99999999",
#                 "custom_sensor_3_param_4_float": null,
#                 "custom_sensor_3_param_4_float_flags": "99999999",
#                 "custom_sensor_3_param_5_float": null,
#                 "custom_sensor_3_param_5_float_flags": "99999999",
#                 "custom_sensor_3_param_6_float": null,
#                 "custom_sensor_3_param_6_float_flags": "99999999",
#                 "custom_sensor_3_param_7_integer": null,
#                 "custom_sensor_3_param_7_integer_flags": "99999999",
#                 "custom_sensor_3_param_8_integer": null,
#                 "custom_sensor_3_param_8_integer_flags": "99999999",
#                 "custom_sensor_3_param_9_integer": null,
#                 "custom_sensor_3_param_9_integer_flags": "99999999",
#                 "echo_well_collection_date": "2019-10-10T02:07:52.384416Z",
#                 "echo_well_depth_high": 0.0,
#                 "echo_well_depth_high_flags": "11111111",
#                 "echo_well_depth_low": 9999.99,
#                 "echo_well_depth_low_flags": "99999999",
#                 "fluor_flth_chl_a_flags": "11111111",
#                 "fluor_flth_chl_a_ugL": null,
#                 "fluor_flth_chl_a_volts": 0.133,
#                 "fluor_flth_collection_date": "2019-10-10T02:07:54.001577Z",
#                 "gnss_gga_bow_collection_date": "2019-10-10T02:07:54.001577Z",
#                 "gnss_gga_bow_latitude": 25.342515,
#                 "gnss_gga_bow_latitude_flags": "11111111",
#                 "gnss_gga_bow_longitude": -149.751801666667,
#                 "gnss_gga_bow_longitude_flags": "11111111",
#                 "gnss_gga_bow_point_flags": "11111111",
#                 "gnss_vtg_bow_cog": 240.5,
#                 "gnss_vtg_bow_cog_flags": "11111111",
#                 "gnss_vtg_bow_collection_date": "2019-10-10T02:07:52.384416Z",
#                 "gnss_vtg_bow_sog": 12.6,
#                 "gnss_vtg_bow_sog_flags": "11111111",
#                 "gyro_brdg_collection_date": "2019-10-10T02:07:52.384416Z",
#                 "gyro_brdg_heading": 244.0,
#                 "gyro_brdg_heading_flags": "11111111",
#                 "metstn_bow_collection_date": null,
#                 "metstn_bow_relative_humidity": null,
#                 "metstn_bow_relative_humidity_flags": "99999999",
#                 "metstn_bow_temperature": null,
#                 "metstn_bow_temperature_flags": "99999999",
#                 "metstn_stbd_collection_date": "2019-10-10T02:07:52.384416Z",
#                 "metstn_stbd_pressure": 1014.5,
#                 "metstn_stbd_pressure_flags": "11111111",
#                 "metstn_stbd_relative_humidity": 99.0,
#                 "metstn_stbd_relative_humidity_flags": "11111111",
#                 "metstn_stbd_temperature": 26.2,
#                 "metstn_stbd_temperature_flags": "11111111",
#                 "par_mmast_collection_date": null,
#                 "par_mmast_par_flags": "99999999",
#                 "par_mmast_par_uEcm2s": null,
#                 "par_mmast_par_volts": null,
#                 "rad_mmast_collection_date": null,
#                 "rad_mmast_pir": null,
#                 "rad_mmast_pir_flags": "99999999",
#                 "rad_mmast_psp": null,
#                 "rad_mmast_psp_flags": "99999999",
#                 "rain_mmast_collection_date": null,
#                 "rain_mmast_rain": null,
#                 "rain_mmast_rain_flags": "99999999",
#                 "sensor_float_1_collection_date": null,
#                 "sensor_float_1_f0": "99999999",
#                 "sensor_float_1_f1": "99999999",
#                 "sensor_float_1_f2": "99999999",
#                 "sensor_float_1_f3": "99999999",
#                 "sensor_float_1_f4": "99999999",
#                 "sensor_float_1_f5": "99999999",
#                 "sensor_float_1_f6": "99999999",
#                 "sensor_float_1_f7": "99999999",
#                 "sensor_float_1_f8": "99999999",
#                 "sensor_float_1_p0": null,
#                 "sensor_float_1_p1": null,
#                 "sensor_float_1_p2": null,
#                 "sensor_float_1_p3": null,
#                 "sensor_float_1_p4": null,
#                 "sensor_float_1_p5": null,
#                 "sensor_float_1_p6": null,
#                 "sensor_float_1_p7": null,
#                 "sensor_float_1_p8": null,
#                 "sensor_float_2_collection_date": null,
#                 "sensor_float_2_f0": "99999999",
#                 "sensor_float_2_f1": "99999999",
#                 "sensor_float_2_f2": "99999999",
#                 "sensor_float_2_f3": "99999999",
#                 "sensor_float_2_f4": "99999999",
#                 "sensor_float_2_f5": "99999999",
#                 "sensor_float_2_f6": "99999999",
#                 "sensor_float_2_f7": "99999999",
#                 "sensor_float_2_f8": "99999999",
#                 "sensor_float_2_p0": null,
#                 "sensor_float_2_p1": null,
#                 "sensor_float_2_p2": null,
#                 "sensor_float_2_p3": null,
#                 "sensor_float_2_p4": null,
#                 "sensor_float_2_p5": null,
#                 "sensor_float_2_p6": null,
#                 "sensor_float_2_p7": null,
#                 "sensor_float_2_p8": null,
#                 "sensor_float_3_collection_date": null,
#                 "sensor_float_3_f0": "99999999",
#                 "sensor_float_3_f1": "99999999",
#                 "sensor_float_3_f2": "99999999",
#                 "sensor_float_3_f3": "99999999",
#                 "sensor_float_3_f4": "99999999",
#                 "sensor_float_3_f5": "99999999",
#                 "sensor_float_3_f6": "99999999",
#                 "sensor_float_3_f7": "99999999",
#                 "sensor_float_3_f8": "99999999",
#                 "sensor_float_3_p0": null,
#                 "sensor_float_3_p1": null,
#                 "sensor_float_3_p2": null,
#                 "sensor_float_3_p3": null,
#                 "sensor_float_3_p4": null,
#                 "sensor_float_3_p5": null,
#                 "sensor_float_3_p6": null,
#                 "sensor_float_3_p7": null,
#                 "sensor_float_3_p8": null,
#                 "sensor_float_4_collection_date": null,
#                 "sensor_float_4_f0": "99999999",
#                 "sensor_float_4_f1": "99999999",
#                 "sensor_float_4_f2": "99999999",
#                 "sensor_float_4_f3": "99999999",
#                 "sensor_float_4_f4": "99999999",
#                 "sensor_float_4_f5": "99999999",
#                 "sensor_float_4_f6": "99999999",
#                 "sensor_float_4_f7": "99999999",
#                 "sensor_float_4_f8": "99999999",
#                 "sensor_float_4_p0": null,
#                 "sensor_float_4_p1": null,
#                 "sensor_float_4_p2": null,
#                 "sensor_float_4_p3": null,
#                 "sensor_float_4_p4": null,
#                 "sensor_float_4_p5": null,
#                 "sensor_float_4_p6": null,
#                 "sensor_float_4_p7": null,
#                 "sensor_float_4_p8": null,
#                 "sensor_float_5_collection_date": null,
#                 "sensor_float_5_f0": "99999999",
#                 "sensor_float_5_f1": "99999999",
#                 "sensor_float_5_f2": "99999999",
#                 "sensor_float_5_f3": "99999999",
#                 "sensor_float_5_f4": "99999999",
#                 "sensor_float_5_f5": "99999999",
#                 "sensor_float_5_f6": "99999999",
#                 "sensor_float_5_f7": "99999999",
#                 "sensor_float_5_f8": "99999999",
#                 "sensor_float_5_p0": null,
#                 "sensor_float_5_p1": null,
#                 "sensor_float_5_p2": null,
#                 "sensor_float_5_p3": null,
#                 "sensor_float_5_p4": null,
#                 "sensor_float_5_p5": null,
#                 "sensor_float_5_p6": null,
#                 "sensor_float_5_p7": null,
#                 "sensor_float_5_p8": null,
#                 "sensor_float_6_collection_date": null,
#                 "sensor_float_6_f0": "99999999",
#                 "sensor_float_6_f1": "99999999",
#                 "sensor_float_6_f2": "99999999",
#                 "sensor_float_6_f3": "99999999",
#                 "sensor_float_6_f4": "99999999",
#                 "sensor_float_6_f5": "99999999",
#                 "sensor_float_6_f6": "99999999",
#                 "sensor_float_6_f7": "99999999",
#                 "sensor_float_6_f8": "99999999",
#                 "sensor_float_6_p0": null,
#                 "sensor_float_6_p1": null,
#                 "sensor_float_6_p2": null,
#                 "sensor_float_6_p3": null,
#                 "sensor_float_6_p4": null,
#                 "sensor_float_6_p5": null,
#                 "sensor_float_6_p6": null,
#                 "sensor_float_6_p7": null,
#                 "sensor_float_6_p8": null,
#                 "sensor_float_7_collection_date": null,
#                 "sensor_float_7_f0": "99999999",
#                 "sensor_float_7_f1": "99999999",
#                 "sensor_float_7_f2": "99999999",
#                 "sensor_float_7_f3": "99999999",
#                 "sensor_float_7_f4": "99999999",
#                 "sensor_float_7_f5": "99999999",
#                 "sensor_float_7_f6": "99999999",
#                 "sensor_float_7_f7": "99999999",
#                 "sensor_float_7_f8": "99999999",
#                 "sensor_float_7_p0": null,
#                 "sensor_float_7_p1": null,
#                 "sensor_float_7_p2": null,
#                 "sensor_float_7_p3": null,
#                 "sensor_float_7_p4": null,
#                 "sensor_float_7_p5": null,
#                 "sensor_float_7_p6": null,
#                 "sensor_float_7_p7": null,
#                 "sensor_float_7_p8": null,
#                 "sensor_integer_1_collection_date": null,
#                 "sensor_integer_1_f0": "99999999",
#                 "sensor_integer_1_f1": "99999999",
#                 "sensor_integer_1_f2": "99999999",
#                 "sensor_integer_1_f3": "99999999",
#                 "sensor_integer_1_f4": "99999999",
#                 "sensor_integer_1_f5": "99999999",
#                 "sensor_integer_1_f6": "99999999",
#                 "sensor_integer_1_f7": "99999999",
#                 "sensor_integer_1_f8": "99999999",
#                 "sensor_integer_1_p0": null,
#                 "sensor_integer_1_p1": null,
#                 "sensor_integer_1_p2": null,
#                 "sensor_integer_1_p3": null,
#                 "sensor_integer_1_p4": null,
#                 "sensor_integer_1_p5": null,
#                 "sensor_integer_1_p6": null,
#                 "sensor_integer_1_p7": null,
#                 "sensor_integer_1_p8": null,
#                 "sensor_mixed_1_collection_date": null,
#                 "sensor_mixed_1_f1": "99999999",
#                 "sensor_mixed_1_f10": "99999999",
#                 "sensor_mixed_1_f11": "99999999",
#                 "sensor_mixed_1_f12": "99999999",
#                 "sensor_mixed_1_f13": "99999999",
#                 "sensor_mixed_1_f14": "99999999",
#                 "sensor_mixed_1_f15": "99999999",
#                 "sensor_mixed_1_f16": "99999999",
#                 "sensor_mixed_1_f17": "99999999",
#                 "sensor_mixed_1_f18": "99999999",
#                 "sensor_mixed_1_f19": "99999999",
#                 "sensor_mixed_1_f2": "99999999",
#                 "sensor_mixed_1_f20": "99999999",
#                 "sensor_mixed_1_f21": "99999999",
#                 "sensor_mixed_1_f22": "99999999",
#                 "sensor_mixed_1_f23": "99999999",
#                 "sensor_mixed_1_f24": "99999999",
#                 "sensor_mixed_1_f3": "99999999",
#                 "sensor_mixed_1_f4": "99999999",
#                 "sensor_mixed_1_f5": "99999999",
#                 "sensor_mixed_1_f6": "99999999",
#                 "sensor_mixed_1_f7": "99999999",
#                 "sensor_mixed_1_f8": "99999999",
#                 "sensor_mixed_1_f9": "99999999",
#                 "sensor_mixed_1_p1": null,
#                 "sensor_mixed_1_p10": null,
#                 "sensor_mixed_1_p11": null,
#                 "sensor_mixed_1_p12": null,
#                 "sensor_mixed_1_p13": null,
#                 "sensor_mixed_1_p14": null,
#                 "sensor_mixed_1_p15": null,
#                 "sensor_mixed_1_p16": null,
#                 "sensor_mixed_1_p17": null,
#                 "sensor_mixed_1_p18": null,
#                 "sensor_mixed_1_p19": null,
#                 "sensor_mixed_1_p2": null,
#                 "sensor_mixed_1_p20": null,
#                 "sensor_mixed_1_p21": "''",
#                 "sensor_mixed_1_p22": "''",
#                 "sensor_mixed_1_p23": "''",
#                 "sensor_mixed_1_p24": "''",
#                 "sensor_mixed_1_p3": null,
#                 "sensor_mixed_1_p4": null,
#                 "sensor_mixed_1_p5": null,
#                 "sensor_mixed_1_p6": null,
#                 "sensor_mixed_1_p7": null,
#                 "sensor_mixed_1_p8": null,
#                 "sensor_mixed_1_p9": null,
#                 "sensor_mixed_2_collection_date": null,
#                 "sensor_mixed_2_f1": "99999999",
#                 "sensor_mixed_2_f10": "99999999",
#                 "sensor_mixed_2_f11": "99999999",
#                 "sensor_mixed_2_f12": "99999999",
#                 "sensor_mixed_2_f13": "99999999",
#                 "sensor_mixed_2_f14": "99999999",
#                 "sensor_mixed_2_f15": "99999999",
#                 "sensor_mixed_2_f16": "99999999",
#                 "sensor_mixed_2_f17": "99999999",
#                 "sensor_mixed_2_f18": "99999999",
#                 "sensor_mixed_2_f19": "99999999",
#                 "sensor_mixed_2_f2": "99999999",
#                 "sensor_mixed_2_f20": "99999999",
#                 "sensor_mixed_2_f21": "99999999",
#                 "sensor_mixed_2_f22": "99999999",
#                 "sensor_mixed_2_f23": "99999999",
#                 "sensor_mixed_2_f24": "99999999",
#                 "sensor_mixed_2_f3": "99999999",
#                 "sensor_mixed_2_f4": "99999999",
#                 "sensor_mixed_2_f5": "99999999",
#                 "sensor_mixed_2_f6": "99999999",
#                 "sensor_mixed_2_f7": "99999999",
#                 "sensor_mixed_2_f8": "99999999",
#                 "sensor_mixed_2_f9": "99999999",
#                 "sensor_mixed_2_p1": null,
#                 "sensor_mixed_2_p10": null,
#                 "sensor_mixed_2_p11": null,
#                 "sensor_mixed_2_p12": null,
#                 "sensor_mixed_2_p13": null,
#                 "sensor_mixed_2_p14": null,
#                 "sensor_mixed_2_p15": null,
#                 "sensor_mixed_2_p16": null,
#                 "sensor_mixed_2_p17": null,
#                 "sensor_mixed_2_p18": null,
#                 "sensor_mixed_2_p19": null,
#                 "sensor_mixed_2_p2": null,
#                 "sensor_mixed_2_p20": null,
#                 "sensor_mixed_2_p21": "''",
#                 "sensor_mixed_2_p22": "''",
#                 "sensor_mixed_2_p23": "''",
#                 "sensor_mixed_2_p24": "''",
#                 "sensor_mixed_2_p3": null,
#                 "sensor_mixed_2_p4": null,
#                 "sensor_mixed_2_p5": null,
#                 "sensor_mixed_2_p6": null,
#                 "sensor_mixed_2_p7": null,
#                 "sensor_mixed_2_p8": null,
#                 "sensor_mixed_2_p9": null,
#                 "sensor_mixed_3_collection_date": null,
#                 "sensor_mixed_3_f1": "99999999",
#                 "sensor_mixed_3_f10": "99999999",
#                 "sensor_mixed_3_f11": "99999999",
#                 "sensor_mixed_3_f12": "99999999",
#                 "sensor_mixed_3_f13": "99999999",
#                 "sensor_mixed_3_f14": "99999999",
#                 "sensor_mixed_3_f15": "99999999",
#                 "sensor_mixed_3_f16": "99999999",
#                 "sensor_mixed_3_f17": "99999999",
#                 "sensor_mixed_3_f18": "99999999",
#                 "sensor_mixed_3_f19": "99999999",
#                 "sensor_mixed_3_f2": "99999999",
#                 "sensor_mixed_3_f20": "99999999",
#                 "sensor_mixed_3_f21": "99999999",
#                 "sensor_mixed_3_f22": "99999999",
#                 "sensor_mixed_3_f23": "99999999",
#                 "sensor_mixed_3_f24": "99999999",
#                 "sensor_mixed_3_f3": "99999999",
#                 "sensor_mixed_3_f4": "99999999",
#                 "sensor_mixed_3_f5": "99999999",
#                 "sensor_mixed_3_f6": "99999999",
#                 "sensor_mixed_3_f7": "99999999",
#                 "sensor_mixed_3_f8": "99999999",
#                 "sensor_mixed_3_f9": "99999999",
#                 "sensor_mixed_3_p1": null,
#                 "sensor_mixed_3_p10": null,
#                 "sensor_mixed_3_p11": null,
#                 "sensor_mixed_3_p12": null,
#                 "sensor_mixed_3_p13": null,
#                 "sensor_mixed_3_p14": null,
#                 "sensor_mixed_3_p15": null,
#                 "sensor_mixed_3_p16": null,
#                 "sensor_mixed_3_p17": null,
#                 "sensor_mixed_3_p18": null,
#                 "sensor_mixed_3_p19": null,
#                 "sensor_mixed_3_p2": null,
#                 "sensor_mixed_3_p20": null,
#                 "sensor_mixed_3_p21": "''",
#                 "sensor_mixed_3_p22": "''",
#                 "sensor_mixed_3_p23": "''",
#                 "sensor_mixed_3_p24": "''",
#                 "sensor_mixed_3_p3": null,
#                 "sensor_mixed_3_p4": null,
#                 "sensor_mixed_3_p5": null,
#                 "sensor_mixed_3_p6": null,
#                 "sensor_mixed_3_p7": null,
#                 "sensor_mixed_3_p8": null,
#                 "sensor_mixed_3_p9": null,
#                 "sensor_point_1_collection_date": null,
#                 "sensor_point_1_f0": "99999999",
#                 "sensor_point_1_f1": "99999999",
#                 "sensor_point_1_f2": "99999999",
#                 "sensor_point_1_f3": "99999999",
#                 "sensor_point_1_p0": null,
#                 "sensor_point_1_p1": null,
#                 "sensor_point_1_p2": null,
#                 "sensor_point_1_p3": null,
#                 "speedlog_well_collection_date": null,
#                 "speedlog_well_heading_magnetic": null,
#                 "speedlog_well_heading_magnetic_flags": "99999999",
#                 "speedlog_well_heading_true": null,
#                 "speedlog_well_heading_true_flags": "99999999",
#                 "speedlog_well_speed_kmhr": null,
#                 "speedlog_well_speed_kmhr_flags": "99999999",
#                 "speedlog_well_speed_knots": null,
#                 "speedlog_well_speed_knots_flags": "99999999",
#                 "therm_fwd_collection_date": "2019-10-10T02:07:54.001577Z",
#                 "therm_fwd_temperature": 27.2372,
#                 "therm_fwd_temperature_flags": "11111111",
#                 "therm_hull_collection_date": null,
#                 "therm_hull_temperature": null,
#                 "therm_hull_temperature_flags": "99999999",
#                 "transmiss_flth_beamc_flags": "11111111",
#                 "transmiss_flth_beamc_percent": null,
#                 "transmiss_flth_beamc_permeter": null,
#                 "transmiss_flth_beamc_volts": 4.104,
#                 "transmiss_flth_collection_date": "2019-10-10T02:07:54.001577Z",
#                 "true_winds_collection_date": "2019-10-10T02:07:52.384416Z",
#                 "true_winds_direction": 105.94,
#                 "true_winds_direction_flags": "99999999",
#                 "true_winds_magnitude": 13.02,
#                 "true_winds_magnitude_flags": "99999999",
#                 "true_winds_u": -12.515182972741,
#                 "true_winds_u_flags": "99999999",
#                 "true_winds_v": 3.57357771458818,
#                 "true_winds_v_flags": "99999999",
#                 "tsg_flth_collection_date": "2019-10-10T02:07:52.384416Z",
#                 "tsg_flth_salinity": 34.8007,
#                 "tsg_flth_salinity_flags": "11111111",
#                 "tsg_flth_temperature": 27.3001,
#                 "tsg_flth_temperature_flags": "11111111"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
## EXAMPLE 3: Query the CORIOLIX REST API - Get the Thermosalinograph data for a user specified window of time

# %%
"""Example script to query the CORIOLIX REST API."""

# Key concepts:
# Use the python requests module to query the REST API
# Use the python json module to parse and dump the json response
# Select a specific sensor endpoint to query.
# Filter results

# Returns:
# Returns a list of all currently valid sensor values

import requests
import json

# URL for Datapresence REST endpoint for the current thermosalinograph table.
base_url = 'https://coriolix.ceoas.oregonstate.edu/oceanus/api/decimateData/?model=TsgFlth'

# Set the start date and time using the ISO8601 format, data stored in UTC
start_date = '2019-10-08T20:00:00Z'
end_date = '2019-10-08T21:00:00Z'

# build the query string
query_url = base_url+'?date_0='+start_date+'&date_1='+end_date+'&format=json'
query_url = base_url+'&date_0=2019-10-10%2002:06:55.353%2B00&decfactr=1&format=json'

# Make the query to the REST API
response = requests.get(query_url, verify=False)

# Load the response as json data
responseJSON = json.loads(response.text)

# Print all thermosalinograph observations
print(json.dumps(responseJSON, indent=4, sort_keys=True))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-19-c68bc21839e6> in <module>
#      27
#      28 # Load the response as json data
# ---> 29 responseJSON = json.loads(response.text)
#      30
#      31 # Print all thermosalinograph observations
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
